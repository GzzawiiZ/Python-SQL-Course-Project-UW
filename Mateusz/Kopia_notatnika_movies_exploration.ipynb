# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.io.gbq.read_gbq('SELECT * FROM projekt-zaliczeniowy-401114.movies.movies',project_id='projekt-zaliczeniowy-401114')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Poster_Link      1000 non-null   object
#  1   Series_Title     1000 non-null   object
#  2   Released_Year    1000 non-null   Int64
#  3   Certificate      899 non-null    object
#  4   IMDB_Rating      1000 non-null   float64
#  5   Overview         1000 non-null   object
#  6   Meta_score       843 non-null    float64
#  7   Director         1000 non-null   object
#  8   Star1            1000 non-null   object
#  9   Star2            1000 non-null   object
#  10  Star3            1000 non-null   object
#  11  Star4            1000 non-null   object
#  12  No_of_Votes      1000 non-null   Int64
#  13  Gross            831 non-null    float64
#  14  Runtime_minutes  1000 non-null   Int64
#  15  Genre1           1000 non-null   object
#  16  Genre2           895 non-null    object
#  17  Genre3           646 non-null    object
# dtypes: Int64(3), float64(3), object(12)
# memory usage: 143.7+ KB

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 2  https://m.media-amazon.com/images/M/MV5BZjA0OW...
# 3  https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 4  https://m.media-amazon.com/images/M/MV5BZjA0MT...
#
#                       Series_Title  Released_Year Certificate  IMDB_Rating  \
# 0         The Shawshank Redemption           1994           A          9.3
# 1                       Fight Club           1999           A          8.8
# 2  One Flew Over the Cuckoo's Nest           1975           A          8.7
# 3                  Soorarai Pottru           2020           U          8.6
# 4               American History X           1998           R          8.5
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An insomniac office worker and a devil-may-car...        66.0
# 2  A criminal pleads insanity and is admitted to ...        83.0
# 3  Nedumaaran Rajangam "Maara" sets out to make t...         NaN
# 4  A former neo-nazi skinhead tries to prevent hi...        62.0
#
#          Director           Star1            Star2             Star3  \
# 0  Frank Darabont     Tim Robbins   Morgan Freeman        Bob Gunton
# 1   David Fincher       Brad Pitt    Edward Norton         Meat Loaf
# 2    Milos Forman  Jack Nicholson  Louise Fletcher  Michael Berryman
# 3   Sudha Kongara          Suriya         Madhavan      Paresh Rawal
# 4       Tony Kaye   Edward Norton   Edward Furlong  Beverly D'Angelo
#
#                Star4  No_of_Votes        Gross  Runtime_minutes Genre1 Genre2  \
# 0     William Sadler      2343110   28341469.0              142  Drama   None
# 1       Zach Grenier      1854740   37030102.0              139  Drama   None
# 2       Peter Brocco       918088  112000000.0              133  Drama   None
# 3  Aparna Balamurali        54995          NaN              153  Drama   None
# 4      Jennifer Lien      1034705    6719864.0              119  Drama   None
#
#   Genre3
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None

# %%
pyt3 = df.loc[:,["IMDB_Rating", "Gross", "Released_Year"]]
pyt3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   IMDB_Rating    1000 non-null   float64
#  1   Gross          831 non-null    float64
#  2   Released_Year  1000 non-null   Int64
# dtypes: Int64(1), float64(2)
# memory usage: 24.5 KB

# %%
plt.plot(pyt3.loc[:,["IMDB_Rating"]],pyt3.loc[:,["Gross"]], 'o')

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#font = {'size': 8}
#plt.rc('font', **font)

x = pyt3["IMDB_Rating"]
y = pyt3["Gross"]
z = pyt3["Released_Year"]

fig = plt.figure()
three_d_plot = Axes3D(fig)
three_d_plot.scatter(x, y, z)
three_d_plot.set_title('IMDB rating - groos income - year of release')
three_d_plot.set_xlabel('IMDB Rating')
three_d_plot.set_ylabel('Gross income')
three_d_plot.set_zlabel('Year of release')
plt.show(block = True)

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Assuming pyt3 is a pandas DataFrame
x = pyt3["IMDB_Rating"]
y = pyt3["Gross"]
z = pyt3["Released_Year"]

fig = plt.figure()
three_d_plot = fig.add_subplot(111, projection='3d')
three_d_plot.scatter(x, y, z)

three_d_plot.set_title('IMDB rating - gross income - year of release')
three_d_plot.set_xlabel('IMDB Rating')
three_d_plot.set_ylabel('Gross income')
three_d_plot.set_zlabel('Year of release')

# Show the plot
plt.show()

# %%
import pandas as pd
import plotly.express as px
df['No_of_Votes'] = df['No_of_Votes'].astype(float)
#fig = px.scatter_3d(df, x = pyt3["IMDB_Rating"], y = pyt3["Gross"], z = pyt3["Released_Year"])
fig = px.scatter_3d(df, x = "IMDB_Rating", y ="Gross", z = "Released_Year", size = 'No_of_Votes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6025864b-c6a5-4c7e-81e9-1cd89ad9ce2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6025864b-c6a5-4c7e-81e9-1cd89ad9ce2e")) {                    Plotly.newPlot(                        "6025864b-c6a5-4c7e-81e9-1cd89ad9ce2e",                        [{"hovertemplate":"IMDB_Rating=%{x}\u003cbr\u003eGross=%{y}\u003cbr\u003eReleased_Year=%{z}\u003cbr\u003eNo_of_Votes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","size":[2343110.0,1854740.0,918088.0,54995.0,1034705.0,62635.0,281623.0,220002.0,33935.0,766870.0,1069738.0,68463.0,146427.0,42341.0,517359.0,33354.0,83005.0,53153.0,120539.0,50700.0,46547.0,720450.0,634716.0,91188.0,57784.0,144911.0,30206.0,26697.0,42940.0,81770.0,428521.0,98575.0,42399.0,289742.0,78341.0,36419.0,86838.0,263918.0,473064.0,27067.0,68926.0,108844.0,28057.0,45062.0,58314.0,99182.0,53818.0,335533.0,56625.0,239473.0,40313.0,51240.0,246963.0,81125.0,30827.0,35682.0,89058.0,62428.0,215034.0,78321.0,133351.0,101124.0,140375.0,77071.0,32001.0,25938.0,40403.0,142863.0,35991.0,224169.0,66941.0,36096.0,47099.0,83363.0,29765.0,95181.0,99643.0,35785.0,41544.0,286770.0,83158.0,65939.0,169708.0,115827.0,27650.0,450474.0,367250.0,143359.0,38737.0,321382.0,717559.0,241575.0,37424.0,211450.0,39881.0,214882.0,31572.0,165465.0,362393.0,27007.0,688390.0,302844.0,232772.0,65659.0,27733.0,1235